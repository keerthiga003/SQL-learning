# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# use de_project;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Employees (
#     EmployeeID INT PRIMARY KEY,
#     FirstName  VARCHAR(50),
#     LastName   VARCHAR(50),
#     Salary     DECIMAL(10,2),
#     Department VARCHAR(50)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO Employees (EmployeeID, FirstName, LastName, Salary, Department)
# VALUES
#     (1, 'Alice', 'Johnson', 55000.00, 'Sales'),
#     (2, 'Bob',   'Smith',   60000.00, 'IT'),
#     (3, 'Carol', 'Davis',   52000.00, 'Sales'),
#     (4, 'Dave',  'Wilson',  58000.00, 'HR');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# []

# %%
# %%sql
# select * from Employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(1, 'Alice', 'Johnson', Decimal('55000.00'), 'Sales'),
#  (2, 'Bob', 'Smith', Decimal('60000.00'), 'IT'),
#  (3, 'Carol', 'Davis', Decimal('52000.00'), 'Sales'),
#  (4, 'Dave', 'Wilson', Decimal('58000.00'), 'HR')]

# %% [markdown]
# view ->A view in SQL is essentially a virtual table that is defined by a SQL query. Unlike a regular table, a view does not store data physically.
#   Instead, it dynamically retrieves data from one or more underlying tables (or even other views) whenever you query it.

# %%
# %%sql
# create view high_earners as
# select EmployeeID, FirstName, LastName, Salary
# from Employees
# where Salary >= 55000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# select * from high_earners;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 3 rows affected.
# [(1, 'Alice', 'Johnson', Decimal('55000.00')),
#  (2, 'Bob', 'Smith', Decimal('60000.00')),
#  (4, 'Dave', 'Wilson', Decimal('58000.00'))]

# %% [markdown]
# if  we add extra record that also include in the view table

# %%
# %%sql
# INSERT INTO Employees (EmployeeID, FirstName, LastName, Salary, Department)
# VALUES
#     (5, 'john', 'son', 57000.00, 'Sales')
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# select * from high_earners;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(1, 'Alice', 'Johnson', Decimal('55000.00')),
#  (2, 'Bob', 'Smith', Decimal('60000.00')),
#  (4, 'Dave', 'Wilson', Decimal('58000.00')),
#  (5, 'john', 'son', Decimal('57000.00'))]
