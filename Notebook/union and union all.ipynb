# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# use de_project;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS employees;
# DROP TABLE IF EXISTS contractors;
#
#
#
# CREATE TABLE employees (
#     employee_id INT AUTO_INCREMENT PRIMARY KEY,
#     first_name  VARCHAR(50),
#     last_name   VARCHAR(50),
#     position    VARCHAR(50),
#     salary      DECIMAL(10,2)
# );
#
# CREATE TABLE contractors (
#     contractor_id INT AUTO_INCREMENT PRIMARY KEY,
#     first_name    VARCHAR(50),
#     last_name     VARCHAR(50),
#     position      VARCHAR(50),
#     hourly_rate   DECIMAL(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO employees (first_name, last_name, position, salary)
# VALUES
# ('Alice', 'Smith', 'Developer', 70000.00),
# ('Bob', 'Johnson', 'Developer', 75000.00),
# ('Charlie', 'Lee', 'Manager', 90000.00);
#
# INSERT INTO contractors (first_name, last_name, position, hourly_rate)
# VALUES
# ('Dave', 'Williams', 'Developer', 40.00),
# ('Eve', 'Brown', 'Tester', 35.00),
# ('Bob', 'Johnson', 'Developer', 45.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 3 rows affected.
# 3 rows affected.
# []

# %% [markdown]
# union -> It remove the duplicate from the two table's  selected  columns result
# --

# %%
# %%sql
# select  first_name from employees
# union
# select first_name from contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Alice',), ('Bob',), ('Charlie',), ('Dave',), ('Eve',)]

# %%
# %%sql
# select * from employees
# union
# select * from contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# [(1, 'Alice', 'Smith', 'Developer', Decimal('70000.00')),
#  (2, 'Bob', 'Johnson', 'Developer', Decimal('75000.00')),
#  (3, 'Charlie', 'Lee', 'Manager', Decimal('90000.00')),
#  (1, 'Dave', 'Williams', 'Developer', Decimal('40.00')),
#  (2, 'Eve', 'Brown', 'Tester', Decimal('35.00')),
#  (3, 'Bob', 'Johnson', 'Developer', Decimal('45.00'))]

# %% [markdown]
# union all ->Two table has the same no.of column and the data type and return the duplicated record also
# --

# %%
# %%sql
# select  first_name from employees
# union all
# select first_name from contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# [('Alice',), ('Bob',), ('Charlie',), ('Dave',), ('Eve',), ('Bob',)]

# %%
# %%sql
# select  * from employees
# union all
# select * from contractors
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# [(1, 'Alice', 'Smith', 'Developer', Decimal('70000.00')),
#  (2, 'Bob', 'Johnson', 'Developer', Decimal('75000.00')),
#  (3, 'Charlie', 'Lee', 'Manager', Decimal('90000.00')),
#  (1, 'Dave', 'Williams', 'Developer', Decimal('40.00')),
#  (2, 'Eve', 'Brown', 'Tester', Decimal('35.00')),
#  (3, 'Bob', 'Johnson', 'Developer', Decimal('45.00'))]
