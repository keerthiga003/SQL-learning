# %% [markdown]
# In SQL, "regex" stands for "regular expression," which is a sequence of characters used to define a search pattern, allowing you to find and manipulate text data within your database by matching complex patterns within strings, rather than just exact matches; essentially providing a powerful tool for searching, extracting, and validating data based on specific character patterns
# within your SQL queries.

# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# USE datetime_vs_timestamp;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE regex_samples (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     sample_text VARCHAR(100)
# );
#
#
# INSERT INTO regex_samples (sample_text) VALUES
# ('apple'),
# ('Banana'),
# ('cherry'),
# ('date'),
# ('elderberry'),
# ('fig'),
# ('grape'),
# ('honeydew'),
# ('running'),
# ('123abc');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 10 rows affected.
# []

# %%
# %%sql
# select * from regex_samples
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 10 rows affected.
# [(1, 'apple'),
#  (2, 'Banana'),
#  (3, 'cherry'),
#  (4, 'date'),
#  (5, 'elderberry'),
#  (6, 'fig'),
#  (7, 'grape'),
#  (8, 'honeydew'),
#  (9, 'running'),
#  (10, '123abc')]

# %% [markdown]
# Match Strings That Start with “a”

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^a';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(1, 'apple')]

# %% [markdown]
# Match Strings That End with “e”

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP 'e$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 3 rows affected.
# [(1, 'apple'), (4, 'date'), (7, 'grape')]

# %% [markdown]
# Match Strings That Start with a Digit

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^[0-9]';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(10, '123abc')]

# %% [markdown]
#  Match Strings Ending with “ing”

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP 'ing$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(9, 'running')]

# %% [markdown]
# Match Strings with Consecutive Repeated Characters

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '(.)\\1';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 4 rows affected.
# [(1, 'apple'), (3, 'cherry'), (5, 'elderberry'), (9, 'running')]

# %% [markdown]
#  Match Strings That Contain Only Letters

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^[A-Za-z]+$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 9 rows affected.
# [(1, 'apple'),
#  (2, 'Banana'),
#  (3, 'cherry'),
#  (4, 'date'),
#  (5, 'elderberry'),
#  (6, 'fig'),
#  (7, 'grape'),
#  (8, 'honeydew'),
#  (9, 'running')]

# %% [markdown]
# Match Strings with Exactly 5 Characters

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^.{5}$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# Match Only “apple” or “banana” Exactly

# %%
# %%sql
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^(apple|banana)$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# [(1, 'apple'), (2, 'Banana')]

# %% [markdown]
# Match Strings Starting with 3 Digits Followed by Letters

# %%
# %%sql
#
# SELECT *
# FROM regex_samples
# WHERE sample_text REGEXP '^[0-9]{3}[A-Za-z]+$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE demo_data (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     full_name VARCHAR(50),
#     phone VARCHAR(25),
#     email VARCHAR(100),
#     date_col VARCHAR(10),   -- Storing as VARCHAR for the demo
#     status VARCHAR(20),
#     sku VARCHAR(20),
#     username VARCHAR(30),
#     notes VARCHAR(100)
# );
#
#
# INSERT INTO demo_data (full_name, phone, email, date_col, status, sku, username, notes)
# VALUES
# -- 1
# ('John Smith',
#  '123-456-7890',
#  'john@example.com',
#  '2025-02-07',
#  'pending',
#  'ABCD',
#  'johnsmith',
#  'Ships to CA'),
#
# -- 2
# ('Alice Johnson',
#  '(987) 654-3210',
#  'alice@@example.net',
#  '2025-02-07',
#  'inactive',
#  'SKU-123',
#  'alice',
#  'NY location'),
#
# -- 3
# ('Bob Williams',
#  '+1-555-123-4567',
#  'bob@sample.org',
#  '20250207',
#  'complete',
#  '1SKU',
#  'bob123',
#  'Shipping to CA'),
#
# -- 4
# ('Mary 1 White',
#  '(123) 123-4567',
#  'mary123@example.com',
#  '2025-13-31',
#  'PENDING',
#  'abc-999',
#  'mary_white',
#  'Something about CA or'),
#
# -- 5
# ('Mark-Spencer',
#  '1234567890',
#  'mark@example.com',
#  '2024-11-02',
#  'active',
#  'SKU-9999',
#  'mark',
#  'Random note'),
#
# -- 6
# ('Jane O''Connor',   -- Note the doubled apostrophe for SQL
#  '987-654-3210',
#  'jane.o.connor@example.org',
#  '2024-12-31',
#  'inactive',
#  'ABCDE',
#  'janeO',
#  'Contains CA or NY'),
#
# -- 7
# ('Invalid Mail',
#  '000-000-0000',
#  'invalid@@example..com',
#  '2023-01-15',
#  'inactive',
#  'XYZ000',
#  'invalid',
#  'Double @ and dots'),
#
# -- 8
# ('NoSpacesHere',
#  '+12-345-678-9012',
#  'nospaces@example.co',
#  '2025-02-07',
#  'pending',
#  'SKU999',
#  'NoSpaces',
#  'Ends with .co domain');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# 8 rows affected.
# []

# %%
# %%sql
# select * from demo_data
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 8 rows affected.
# [(1, 'John Smith', '123-456-7890', 'john@example.com', '2025-02-07', 'pending', 'ABCD', 'johnsmith', 'Ships to CA'),
#  (2, 'Alice Johnson', '(987) 654-3210', 'alice@@example.net', '2025-02-07', 'inactive', 'SKU-123', 'alice', 'NY location'),
#  (3, 'Bob Williams', '+1-555-123-4567', 'bob@sample.org', '20250207', 'complete', '1SKU', 'bob123', 'Shipping to CA'),
#  (4, 'Mary 1 White', '(123) 123-4567', 'mary123@example.com', '2025-13-31', 'PENDING', 'abc-999', 'mary_white', 'Something about CA or'),
#  (5, 'Mark-Spencer', '1234567890', 'mark@example.com', '2024-11-02', 'active', 'SKU-9999', 'mark', 'Random note'),
#  (6, "Jane O'Connor", '987-654-3210', 'jane.o.connor@example.org', '2024-12-31', 'inactive', 'ABCDE', 'janeO', 'Contains CA or NY'),
#  (7, 'Invalid Mail', '000-000-0000', 'invalid@@example..com', '2023-01-15', 'inactive', 'XYZ000', 'invalid', 'Double @ and dots'),
# ...

# %% [markdown]
# Matching a Strict Date Format (YYYY-MM-DD)

# %%
# %%sql
# SELECT *
# FROM demo_data
# WHERE date_col REGEXP '^[0-9][0-9][0-9][0-9]-[0-9]{2}-[0-9]{2}$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# Matching Names Containing Only Letters and Spaces

# %%
# %%sql
# SELECT *
# FROM demo_data
# WHERE full_name REGEXP '^[A-Za-z ]+$';
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(1, 'John Smith', '123-456-7890', 'john@example.com', '2025-02-07', 'pending', 'ABCD', 'johnsmith', 'Ships to CA'),
#  (2, 'Alice Johnson', '(987) 654-3210', 'alice@@example.net', '2025-02-07', 'inactive', 'SKU-123', 'alice', 'NY location'),
#  (3, 'Bob Williams', '+1-555-123-4567', 'bob@sample.org', '20250207', 'complete', '1SKU', 'bob123', 'Shipping to CA'),
#  (7, 'Invalid Mail', '000-000-0000', 'invalid@@example..com', '2023-01-15', 'inactive', 'XYZ000', 'invalid', 'Double @ and dots'),
#  (8, 'NoSpacesHere', '+12-345-678-9012', 'nospaces@example.co', '2025-02-07', 'pending', 'SKU999', 'NoSpaces', 'Ends with .co domain')]
