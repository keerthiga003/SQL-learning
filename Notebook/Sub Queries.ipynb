# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:root@localhost

# %%
# %%sql
# use de_project;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE Customers (
#     customer_id INT PRIMARY KEY,
#     customer_name VARCHAR(100),
#     city VARCHAR(100)
#
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO Customers VALUES
# (1, 'Ravi Kumar','Chennai'),
# (2, 'Priya Sharma','Bangalore'),
# (3, 'Arjun Mehta', 'Hyderabad'),
# (4, 'Meena Gupta', 'Mumbai'),
# (5, 'Karthik Raj', 'Chennai');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# []

# %%
# %%sql
# select * from Customers
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(1, 'Ravi Kumar', 'Chennai'),
#  (2, 'Priya Sharma', 'Bangalore'),
#  (3, 'Arjun Mehta', 'Hyderabad'),
#  (4, 'Meena Gupta', 'Mumbai'),
#  (5, 'Karthik Raj', 'Chennai')]

# %%
# %%sql
# create table orders(
#     order_id INT PRIMARY KEY,
#     customer_id INT NOT NULL,
#     order_amount INT NOT  NULL,
#     order_date DATE NOT NULL)
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# insert into orders(order_id,customer_id,order_amount,order_date) values
# (101,1,5000.00,'2025-01-01'),
# (102,2,10000.00,'2025-01-02'),
# (103,3,3000.00,'2025-01-03'),
# (104,4,1500.00,'2025-01-04'),
# (105,1,2000.00,'2025-01-05'),
# (106,5,8000.00,'2025-01-06')
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# []

# %%
# %%sql
# select * from orders
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 6 rows affected.
# [(101, 1, 5000, datetime.date(2025, 1, 1)),
#  (102, 2, 10000, datetime.date(2025, 1, 2)),
#  (103, 3, 3000, datetime.date(2025, 1, 3)),
#  (104, 4, 1500, datetime.date(2025, 1, 4)),
#  (105, 1, 2000, datetime.date(2025, 1, 5)),
#  (106, 5, 8000, datetime.date(2025, 1, 6))]

# %%
# %%sql
# select * from Customers
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(1, 'Ravi Kumar', 'Chennai'),
#  (2, 'Priya Sharma', 'Bangalore'),
#  (3, 'Arjun Mehta', 'Hyderabad'),
#  (4, 'Meena Gupta', 'Mumbai'),
#  (5, 'Karthik Raj', 'Chennai')]

# %%
# %%sql
# select
# customer_name,
# (select max(order_amount) from orders) as max_order_amount
# from Customers
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Ravi Kumar', 10000),
#  ('Priya Sharma', 10000),
#  ('Arjun Mehta', 10000),
#  ('Meena Gupta', 10000),
#  ('Karthik Raj', 10000)]

# %% [markdown]
# sub queries in where condition

# %%
# %%sql
# select
# customer_name
# from Customers
# where customer_id in(
#     select distinct customer_id
#     from orders
#     where order_amount >= 5000
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 3 rows affected.
# [('Ravi Kumar',), ('Priya Sharma',), ('Karthik Raj',)]

# %% [markdown]
# 1.in ->it return if the specific value is present in the table
# 2.exists ->it returns if the  condition is statisfied in the first record then it return all the records in the table

# %%
# %%sql
# select
# customer_name
# from Customers
# where exists(
#     select *
#     from Customers where city="chennai" #here the chennai is present in the table so the ondition is statisfied for the first record so it return  all the record in the table
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Ravi Kumar',),
#  ('Priya Sharma',),
#  ('Arjun Mehta',),
#  ('Meena Gupta',),
#  ('Karthik Raj',)]

# %%
# %%sql
# select
# customer_name
# from Customers
# where exists(
#     select *
#     from Customers where city="karur"  # here karur is not present in the table so it not give anything
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# select
#     customer_name,
#     city,
#     (select sum(order_amount)
#     from orders o
#     where o.customer_id = c.customer_id) as total_orders
# from Customers c;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Ravi Kumar', 'Chennai', Decimal('7000')),
#  ('Priya Sharma', 'Bangalore', Decimal('10000')),
#  ('Arjun Mehta', 'Hyderabad', Decimal('3000')),
#  ('Meena Gupta', 'Mumbai', Decimal('1500')),
#  ('Karthik Raj', 'Chennai', Decimal('8000'))]

# %% [markdown]
# sub queries in case

# %%
# %%sql
# select
#     customer_name,
#     case
#         when (select sum(order_amount) from orders where orders.customer_id = Customers.customer_id) >
#             (select avg(order_amount) from orders) then "Above Average"
#         else "Below Average"
#     end as order_category
# from Customers;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [('Ravi Kumar', 'Above Average'),
#  ('Priya Sharma', 'Above Average'),
#  ('Arjun Mehta', 'Below Average'),
#  ('Meena Gupta', 'Below Average'),
#  ('Karthik Raj', 'Above Average')]

# %% [markdown]
# sub queries in select

# %%
# %%sql
# select name_length
# from(
# select
#     customer_name,
#     length(customer_name) as name_length,
#     upper(customer_name) as upper_name
#   from Customers
# )as subquery
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 5 rows affected.
# [(10,), (12,), (11,), (11,), (11,)]
